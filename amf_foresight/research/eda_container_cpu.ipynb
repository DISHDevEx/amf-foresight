# %%
import os
os.chdir('/root/amf-foresight/amf_foresight')
from eda import EDA
from load_data import AMFDataProcessor
from feature_engineering import FeatureEngineer
from setup_logger import setup_logger
eda = EDA()
load = AMFDataProcessor()
feature = FeatureEngineer

# %%
spark = load.get_all_amf_data('jsons/20230606 140000-20230606 160000.json')
# Out:
# Nested_Json_Connector initialized with the following s3_file_path:jsons/20230606 140000-20230606 160000.json

# %% [markdown]
# # Container: CPU

# %% [markdown]
# ## container_cpu_load_average_10s (Average Load on CPU)(Units: None)

# %%
transform_spark = load. transform_dataframe(spark, 'container_cpu_load_average_10s')
eda.plotly_plot(transform_spark, 'container_cpu_load_average_10s')
# Out:
# Time taken to plot this:  18.038790941238403

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_cpu_loa...|[0.0, 0.0, 0.0, 0...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_cpu_loa...|[0.0, 0.0, 0.0, 0...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_cpu_system_seconds_total (CPU Usage seconds by System Space)(Units: s)

# %%
transform_spark = load. transform_dataframe(spark, 'container_cpu_system_seconds_total')
eda.plotly_plot(transform_spark, 'container_cpu_system_seconds_total')
# Out:
# Time taken to plot this:  16.910252571105957

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_cpu_sys...|[0.04, 0.04, 0.05...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_cpu_sys...|[0.01, 0.02, 0.02...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_cpu_user_seconds_total (CPU Usage by User Space)(Units: s)

# %%
transform_spark = load. transform_dataframe(spark, 'container_cpu_user_seconds_total')
eda.plotly_plot(transform_spark, 'container_cpu_user_seconds_total')
# Out:
# Time taken to plot this:  11.421191215515137

# %% [markdown]
# ## container_cpu_usage_seconds_total (CPU Usage by System + User Space)(Units: s)

# %%
transform_spark = load. transform_dataframe(spark, 'container_cpu_usage_seconds_total')
eda.plotly_plot(transform_spark, 'container_cpu_usage_seconds_total')
# Out:
# Time taken to plot this:  9.28045916557312

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_cpu_usa...|[0.049779036, 0.0...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_cpu_usa...|[0.052241893, 0.0...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_spec_cpu_period (Duration of a single scheduling period)(Units: micro-s)

# %%
transform_spark = load. transform_dataframe(spark, 'container_spec_cpu_period')
eda.plotly_plot(transform_spark, 'container_spec_cpu_period')
# Out:
# Time taken to plot this:  9.505625486373901

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063489928, 1...|container_spec_cp...|[100000.0, 100000...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062499928, 1...|container_spec_cp...|[100000.0, 100000...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_spec_cpu_shares (Distribution of CPU resources among containers)(Unit: ratio)

# %%
transform_spark = load. transform_dataframe(spark, 'container_spec_cpu_shares')
eda.plotly_plot(transform_spark, 'container_spec_cpu_shares')
# Out:
# Time taken to plot this:  9.521291017532349

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063489928, 1...|container_spec_cp...|[2.0, 2.0, 2.0, 2...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062499928, 1...|container_spec_cp...|[2.0, 2.0, 2.0, 2...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_processes (Count of running processes in a container)(Unit: count)

# %%
transform_spark = load. transform_dataframe(spark, 'container_processes')
eda.plotly_plot(transform_spark, 'container_processes')
# Out:
# Time taken to plot this:  9.23237681388855

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+-------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|    metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+-------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_processes|[2.0, 2.0, 2.0, 2...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_processes|[2.0, 2.0, 2.0, 2...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_threads (Count of running threads in a container)(Unit: count)

# %%
transform_spark = load. transform_dataframe(spark, 'container_threads')
eda.plotly_plot(transform_spark, 'container_threads')
# Out:
# Time taken to plot this:  8.695234775543213

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+-----------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|  metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+-----------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_threads|[3.0, 3.0, 3.0, 3...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_threads|[3.0, 3.0, 3.0, 3...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...

# %% [markdown]
# ## container_threads_max (Maximum number of running threads allowed in a container)(Unit: count)

# %%
transform_spark = load. transform_dataframe(spark, 'container_threads_max')
eda.plotly_plot(transform_spark, 'container_threads_max')
# Out:
# Time taken to plot this:  8.59299349784851

# %%
transform_spark.select('timestamps', 'metric___name__', 'values', 'metric_pod', 'metric_container', 'metric_name', 'metric_image', 'metric_id', 'metric_namespace').show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |          timestamps|     metric___name__|              values|          metric_pod|metric_container|         metric_name|        metric_image|           metric_id|metric_namespace|
# +--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+----------------+
# |[1686063479849, 1...|container_threads...|[0.0, 0.0, 0.0, 0...|open5gs-amf-6d85b...|     open5gs-amf|04e301394b9cf3061...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# |[1686062484067, 1...|container_threads...|[0.0, 0.0, 0.0, 0...|open5gs-amf-6d85b...|     open5gs-amf|7f3f44350d0b34386...|docker.io/openver...|/kubepods.slice/k...|       openverso|
# ...
